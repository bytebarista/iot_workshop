# %% [markdown]
# Chapters - subchapters
#
# TOC + links/resources
# 0. - Getting started
#   - intro to micropython
#   - ESP32
#   - flashing/installing
#   - copying files
#   - REPL
# 1. Basics/components
#   - GPIO (Pin)
#   - PWM
#   - SPI
#     - Display
#     - MicroSD reader
#   - I2C
#     - IO extender
#     - bme280
#     - mpu9250
#   - ADC/DAC
#     - thumbslide
#     - speaker
#     - microphone
#   - Wifi
#
#   - MCU vs PC
#     - factorial
#   - scheduling/interrupts/timer
#
#
#
#   - Fade led when holding button
#   - move dot on display with thumbslide input (+ change color on button click)
#   - display image on screen
#   - Movement alarm
#   - LED driver
#   - Amplitude graph on display
#   - temperature on display
#
#
#   - local temp + weather report (urequests)
#   - Remote control tank
#   - Labyrinth tilt game
#   - Pacman game
#   - walkie-talkie
#   - fft on display
#   - raytracer
#   - simons game
#   - multiplayer pong
#
#   - Theory: SPI
#   - Component: Display
#   - Task: Button state on Display
#   - Task: Button state on Display
#   - Component: Display
#   - Theory: SPI
#   - Task: Button state on Display
#
#
# 3.
#   - LEDs APA102
