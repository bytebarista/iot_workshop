# %% [markdown]
# Chapters - subchapters
#
# TOC + links/resources
# 0. - Getting started
#   - intro to micropython
#   - ESP32
#   - flashing/installing
#   - copying files
#   - REPL
# 1. Basics/components
#   - GPIO (Pin)
#   - PWM
#   - SPI
#     - Display
#     - MicroSD reader
#   - I2C
#     - IO extender
#     - bme280
#     - mpu9250
#   - ADC/DAC
#     - thumbslide
#     - speaker
#     - microphone
#   - Wifi
#
#   - MCU vs PC
#     - factorial
#   - scheduling/interrupts/timer
#
# ### Miscellaneous
# - garbage collector gc
#
#
# ## Small tasks
#
#   - Fade led when holding button
#   - move dot on display with thumbslide input (+ change color on button click)
#   - display image on screen
#   - Movement alarm
#   - LED driver
#   - Amplitude graph on display
#   - temperature on display
#   - wake up from deep sleep
#   - connect to webrepl
#   - debouncing an input pin ([example](https://docs.micropython.org/en/latest/pyboard/tutorial/debounce.html))
#   - make a [framebuffer](https://docs.micropython.org/en/latest/library/framebuf.html)
#   - use cooperative scheduling (uasyncio)
#
# ## Exercises
#   - optimize some slow Python code
#     - const type
#   - local temp + weather report (urequests)
#   - display touch driver
#   - Remote control tank
#   - Labyrinth tilt game
#   - Pacman game
#   - walkie-talkie
#   - fft on display
#   - raytracer
#   - simons game
#   - multiplayer pong
#   - mp3 player (https://github.com/MrBuddyCasino/ESP32_MP3_Decoder)
#   - LEDs APA102 driver
#   - make a c interface with [uctypes](https://docs.micropython.org/en/latest/library/uctypes.html)
#
# ## structure suggestion
#   - Theory: SPI
#   - Component: Display
#   - Task: Button state on Display
#   - Task: Button state on Display
#   - Component: Display
#   - Theory: SPI
#   - Task: Button state on Display
#
# ## notable libraries/modules
#
# ### builtin
# - [the standard library](https://docs.micropython.org/en/latest/library/index.html#python-standard-libraries-and-micro-libraries)
# - [micropython](https://docs.micropython.org/en/latest/library/micropython.html)
# - [machine](https://docs.micropython.org/en/latest/library/machine.html)
# - [ustruct](https://docs.micropython.org/en/latest/library/ustruct.html)
#
#
# ### esp32 specific
#
# ### external
